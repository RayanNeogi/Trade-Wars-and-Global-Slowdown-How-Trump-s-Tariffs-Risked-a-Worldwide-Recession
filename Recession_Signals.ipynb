# %%
# !pip install pandas semopy openpyxl matplotlib
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 17.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.2/100.2 kB 7.5 MB/s eta 0:00:00
# ...
#   Created wheel for semopy: filename=semopy-2.3.11-py3-none-any.whl size=1659682 sha256=e807ec45170f31adc277013938911f61a145b817ac8803323064432a46c374a6
#   Stored in directory: /root/.cache/pip/wheels/d2/9a/31/fae291ff6a649bad125037eef8c7cc63d8c542e14bdcccea37
# Successfully built semopy
# ...

# %%
import pandas as pd
from semopy import Model
import matplotlib.pyplot as plt

# %%
file_path = 'semifinal_data.xlsx'
df = pd.read_excel(file_path, sheet_name='Sheet1')
df['observation_date'] = pd.to_datetime(df['observation_date'])
df.head()
# Out:
#   observation_date  Real_GDP  Tariff_Revenue  Real_Imports  Yield_Curve
# 0       1976-07-01  6404.895           4.748       155.848         1.10
# 1       1976-10-01  6451.177           4.628       162.680         1.47
# 2       1977-01-01  6527.703           5.028       176.433         1.33
# 3       1977-04-01  6654.466           5.312       183.042         1.25
# 4       1977-07-01  6774.457           5.768       182.904         0.81

# %%
df = df.dropna(subset=['Real_GDP', 'Tariff_Revenue', 'Real_Imports', 'Yield_Curve'])

# %%
model_desc = """
Yield_Curve ~ Real_GDP + Tariff_Revenue + Real_Imports
"""

# Fit the model
model = Model(model_desc)
model.fit(df)
# Out:
# SolverResult(fun=np.float64(2.2441634328629334e-08), success=np.True_, n_it=9, x=array([ 1.48082664e-04, -3.08091200e-02, -1.08298253e-05,  6.78251827e-01]), message='Optimization terminated successfully', name_method='SLSQP', name_obj='MLW')

# %%
model.inspect()
# Out:
#           lval  op            rval  Estimate  Std. Err   z-value       p-value
# 0  Yield_Curve   ~        Real_GDP  0.000148  0.000067  2.196356  2.806649e-02
# 1  Yield_Curve   ~  Tariff_Revenue -0.030809  0.005128 -6.008330  1.874440e-09
# 2  Yield_Curve   ~    Real_Imports -0.000011  0.000296 -0.036602  9.708027e-01
# 3  Yield_Curve  ~~     Yield_Curve  0.678252  0.068689  9.874209  0.000000e+00
